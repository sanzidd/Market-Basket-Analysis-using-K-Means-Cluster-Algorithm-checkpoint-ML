# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings as wr
wr.filterwarnings('ignore')

# %%
df = pd.read_csv('mall customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.shape
# Out:
# (200, 5)

# %%
df.drop(['CustomerID','Gender'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age  Annual Income (k$)  Spending Score (1-100)
# 0   19                  15                      39
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77
# 4   31                  17                      40

# %%
#df = df.rename(columns={'Age': 'age', 'Annual Income (k$)':'income', 'Spending Score (1-100)':'score'})
df.rename(columns={'Age': 'age', 'Annual Income (k$)':'income', 'Spending Score (1-100)':'score'}, inplace=True)

# %%
df.head()
# Out:
#    age  income  score
# 0   19      15     39
# 1   21      15     81
# 2   20      16      6
# 3   23      16     77
# 4   31      17     40

# %%
df.shape
# Out:
# (200, 3)

# %%
plt.scatter(df.age, df.income)
plt.show()

# %%
plt.scatter(df.age, df.score)
plt.show()

# %%
plt.scatter(df.score, df.income)
plt.show()

# %%
sns.pairplot(df[['age','income','score']])
plt.savefig('image.png')

# %% [markdown]
# # KMEANS CLUSTER

# %% [markdown]
# [KMeans Cluster](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)

# %% [markdown]
# [Download this Cheatsheet](https://github.com/rashakil-ds/Top-Data-Science-AI-Book-Collection/blob/main/Other%20Docs/Clustering%20Algorithms.pdf)

# %%
plt.scatter(df.score, df.income) 
plt.xlabel('SCORE')
plt.ylabel('INCOME')
plt.show()

# %%
# https://prnt.sc/K9UUIaqJEf2G

# %%
from sklearn.cluster import KMeans
km1 = KMeans() #default cluster = 8

# %%
km1.fit_predict(df[['income', 'score']])
# Out:
# array([4, 5, 4, 5, 4, 5, 4, 3, 4, 5, 4, 3, 4, 5, 4, 5, 4, 5, 4, 3, 4, 5,
#        4, 5, 4, 5, 4, 5, 4, 3, 4, 5, 4, 3, 4, 5, 4, 5, 4, 5, 4, 3, 4, 5,
#        4, 5, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 1, 0, 1, 0, 7, 0, 7, 0,
#        1, 0, 7, 0, 7, 0, 7, 0, 7, 0, 1, 0, 7, 0, 1, 0, 1, 0, 7, 0, 7, 0,
#        7, 0, 7, 0, 7, 0, 1, 0, 7, 0, 1, 0, 7, 0, 1, 0, 7, 0, 7, 0, 7, 0,
#        7, 0, 7, 0, 1, 0, 7, 0, 1, 0, 1, 6, 7, 6, 1, 6, 7, 6, 7, 6, 1, 6,
#        7, 6], dtype=int32)

# %%
df.head()
# Out:
#    age  income  score
# 0   19      15     39
# 1   21      15     81
# 2   20      16      6
# 3   23      16     77
# 4   31      17     40

# %%
df['km1_cluster'] = km1.fit_predict(df[['income', 'score']])
df.head()
# Out:
#    age  income  score  km1_cluster
# 0   19      15     39            7
# 1   21      15     81            4
# 2   20      16      6            3
# 3   23      16     77            4
# 4   31      17     40            7

# %%
km1.predict([[20, 37]])
# Out:
# array([7], dtype=int32)

# %%
km1.cluster_centers_
# Out:
# array([[ 55.64      ,  50.26666667],
#        [109.7       ,  22.        ],
#        [ 84.        ,  90.47368421],
#        [ 24.58333333,   9.58333333],
#        [ 25.72727273,  79.36363636],
#        [ 88.95      ,  74.2       ],
#        [ 79.        ,  16.59259259],
#        [ 31.53333333,  35.86666667]])

# %%
df8 = df[df.km1_cluster==7]

# %%
df8
# Out:
#     age  income  score  km1_cluster
# 0    19      15     39            7
# 4    31      17     40            7
# 16   35      21     35            7
# 18   52      23     29            7
# 20   35      24     35            7
# 26   45      28     32            7
# 28   40      29     31            7
# 38   36      37     26            7
# 40   65      38     35            7
# 42   48      39     36            7
# 44   49      39     28            7
# 47   27      40     47            7
# 48   29      40     42            7
# 49   31      40     42            7
# 55   47      43     41            7

# %%
plt.scatter(df8.score, df8.income) 
plt.xlabel('SCORE')
plt.ylabel('INCOME')
plt.show()

# %%
df1 = df[df.km1_cluster==0]
df2 = df[df.km1_cluster==1]
df3 = df[df.km1_cluster==2]
df4 = df[df.km1_cluster==3]
df5 = df[df.km1_cluster==4]
df6 = df[df.km1_cluster==5]
df7 = df[df.km1_cluster==6]

# %%
plt.figure(figsize=(12,8))

plt.scatter(df8.score, df8.income, label='cluster_0') 
plt.scatter(df1.score, df1.income, label='cluster_1') 
plt.scatter(df2.score, df2.income,  label='cluster_2') 
plt.scatter(df3.score, df3.income, label='cluster_3')
plt.scatter(df4.score, df4.income, label='cluster_4') 
plt.scatter(df5.score, df5.income, label='cluster_5') 
plt.scatter(df6.score, df6.income, label='cluster_6') 
plt.scatter(df7.score, df7.income, label='cluster_7') 

plt.legend()
plt.xlabel('SCORE')
plt.ylabel('INCOME')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12,8))
sns.scatterplot(data=df, x='score', y='income', hue='km1_cluster' )
# Out:
# <Axes: xlabel='score', ylabel='income'>

# %% [markdown]
# # Within-Cluster Sum of Squares (WCSS): How many clusters are good enough?

# %%
wcss = []

for i in range(1,15):
    km2 = KMeans(n_clusters=i)
    km2.fit(df[['income', 'score']])
    wcss.append(km2.inertia_)

# %%
wcss
# Out:
# [269981.28,
#  181665.82312925172,
#  106348.37306211119,
#  99458.83963720276,
#  44448.45544793371,
#  37271.886236589504,
#  33859.371012691015,
#  30174.67399267399,
#  23312.62154166588,
#  25332.89590066796,
#  18295.781918603217,
#  16657.605433214132,
#  16581.665818037116,
#  13327.902268874057]

# %%
plt.plot(range(1,15), wcss, marker='o')

# %%
pip install Kneed
# Out:
# Collecting Kneed
#   Downloading kneed-0.8.5-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.14.2 in /opt/anaconda3/lib/python3.13/site-packages (from Kneed) (2.3.5)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from Kneed) (1.16.3)
# Downloading kneed-0.8.5-py3-none-any.whl (10 kB)
# Installing collected packages: Kneed
# Successfully installed Kneed-0.8.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from kneed import KneeLocator

# %%
kne = KneeLocator(range(1,15), wcss, curve='convex', direction='decreasing')

# %%
kne

# %%
kne.plot_knee()

# %%
kne.knee
# Out:
# np.int64(5)

# %% [markdown]
# # Finally

# %%
km3 = KMeans(n_clusters=5)

# %%
df['km1_cluster'] = km3.fit_predict(df[['income', 'score']])
df.head()
# Out:
#    age  income  score  km1_cluster
# 0   19      15     39            3
# 1   21      15     81            0
# 2   20      16      6            3
# 3   23      16     77            0
# 4   31      17     40            3

# %%
km3.cluster_centers_
# Out:
# array([[25.72727273, 79.36363636],
#        [55.2962963 , 49.51851852],
#        [88.2       , 17.11428571],
#        [26.30434783, 20.91304348],
#        [86.53846154, 82.12820513]])

# %%
df1 = df[df.km1_cluster==0]
df2 = df[df.km1_cluster==1]
df3 = df[df.km1_cluster==2]
df4 = df[df.km1_cluster==3]
df5 = df[df.km1_cluster==4]

plt.figure(figsize=(12,8))
 
plt.scatter(df1.score, df1.income, label='cluster_1') 
plt.scatter(df2.score, df2.income,  label='cluster_2') 
plt.scatter(df3.score, df3.income, label='cluster_3')
plt.scatter(df4.score, df4.income, label='cluster_4') 
plt.scatter(df5.score, df5.income, label='cluster_5') 

plt.scatter(km3.cluster_centers_[:,0], km3.cluster_centers_[:,1], label='centroid', color='black', marker='*')

plt.legend()
plt.xlabel('SCORE')
plt.ylabel('INCOME')
plt.show()
